# %%
import pandas as pd

df = pd.read_csv('market_price.tsv', sep="\t")
df.head()
# Out:
#        time      mid
# 0  09:00:00  111.081
# 1  09:01:00  111.452
# 2  09:02:00  111.192
# 3  09:03:00  110.673
# 4  09:04:00  111.104

# %%
import matplotlib.pyplot as plt

plt.plot(df.time[:30], df.mid[:30])

# %%
df.dtypes
# Out:
# time     object
# mid     float64
# dtype: object
