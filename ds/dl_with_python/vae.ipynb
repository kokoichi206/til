# %%
from tensorflow import keras
from tensorflow.keras import layers

latent_dim = 2
encoder_inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(
    32, 3, activation="relu", strides=2, padding="same")(encoder_inputs)
x = layers.Conv2D(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Flatten()(x)
x = layers.Dense(16, activation="relu")(x)

# 入力画像をこれら２つのパラメータにエンコード
z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var], name="encoder")

encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 14, 14, 32)   320         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 7, 7, 64)     18496       ['conv2d[0][0]']
#
#  flatten (Flatten)              (None, 3136)         0           ['conv2d_1[0][0]']
#
#  dense (Dense)                  (None, 16)           50192       ['flatten[0][0]']
#
#  z_mean (Dense)                 (None, 2)            34          ['dense[0][0]']
#
#  z_log_var (Dense)              (None, 2)            34          ['dense[0][0]']
#
# ==================================================================================================
# Total params: 69,076
# Trainable params: 69,076
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import tensorflow as tf

class Sampler(layers.Layer):
    def call(self, z_mean, z_log_var):
        batch_size = tf.shape(z_mean)[0]
        z_size = tf.shape(z_mean)[1]

        # ランダムな正規ベクトルをバッチデータとして抽出
        epsilon = tf.random.normal(shape=(batch_size, z_size))
        # VAEのサンプリングの式を適応
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
latent_inputs = keras.Input(shape=(latent_dim, ))

# エンコーダのFlatten層のレベルで使ったのと同じ数の係数を生成
x = layers.Dense(7 * 7 * 64, activation="relu")(latent_inputs)

# エンコーダーのFlatten層をもとに戻す
x = layers.Reshape((7, 7, 64))(x)

# エンコーダーのConv2Dをもとに戻す
x = layers.Conv2DTranspose(
    64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(
    32, 3, activation="relu", strides=2, padding="same")(x)

# 最終的な出力の形状は(28, 28, 1).
decoder_outputs = layers.Conv2D(1, 3, activation="sigmoid", padding="same")(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")

decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_1 (Dense)             (None, 3136)              9408
#
#  reshape (Reshape)           (None, 7, 7, 64)          0
#
#  conv2d_transpose (Conv2DTra  (None, 14, 14, 64)       36928
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 28, 28, 32)       18464
#  ranspose)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 65,089
# Trainable params: 65,089
# Non-trainable params: 0
# _________________________________________________________________

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.sampler = Sampler()
        
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss")
        self.kl_loss_tracker = keras.metrics.Mean("kl_loss")
    
    @property
    def metrics(self):
        return [self.total_loss_tracker,
                self.reconstruction_loss_tracker,
                self.kl_loss_tracker]
    
    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var = self.encoder(data)
            z = self.sampler(z_mean, z_log_var)
            reconstruction = decoder(z)

            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data, reconstruction),
                    axis=(1, 2)
                )
            )

            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            total_loss = reconstruction_loss + tf.reduce_mean(kl_loss)
        
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "total_loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %%
import numpy as np

(x_train, _), (x_test, _) = keras.datasets.mnist.load_data()

mnist_digits = np.concatenate([x_train, x_test], axis=0)
mnist_digits = np.expand_dims(mnist_digits, -1).astype("float32") / 255

vae = VAE(encoder, decoder)

# 損失関数は既に train_step() に含まれているので、compile() に引数として渡さない
vae.compile(optimizer=keras.optimizers.Adam(), run_eagerly=True)

# train_step() は目的値を必要としないため、fit() では目的値を渡さない
vae.fit(mnist_digits, epochs=30, batch_size=128)
# Out:
# Epoch 1/30
# 547/547 [==============================] - 18s 31ms/step - total_loss: 208.3213 - reconstruction_loss: 206.0467 - kl_loss: 2.2746
# Epoch 2/30
# 547/547 [==============================] - 21s 38ms/step - total_loss: 178.4605 - reconstruction_loss: 175.3530 - kl_loss: 3.1074
# Epoch 3/30
# 547/547 [==============================] - 21s 39ms/step - total_loss: 163.6866 - reconstruction_loss: 159.8866 - kl_loss: 3.8000
# Epoch 4/30
# 547/547 [==============================] - 22s 40ms/step - total_loss: 159.0412 - reconstruction_loss: 155.1503 - kl_loss: 3.8907
# Epoch 5/30
# 547/547 [==============================] - 22s 40ms/step - total_loss: 156.4471 - reconstruction_loss: 152.5386 - kl_loss: 3.9085
# Epoch 6/30
# 547/547 [==============================] - 23s 42ms/step - total_loss: 154.8459 - reconstruction_loss: 150.9361 - kl_loss: 3.9098
# Epoch 7/30
# 547/547 [==============================] - 23s 41ms/step - total_loss: 153.6128 - reconstruction_loss: 149.7080 - kl_loss: 3.9049
# Epoch 8/30
# 547/547 [==============================] - 22s 40ms/step - total_loss: 152.6303 - reconstruction_loss: 148.7052 - kl_loss: 3.9251
# Epoch 9/30
# 547/547 [==============================] - 20s 36ms/step - total_loss: 151.9882 - reconstruction_loss: 148.0799 - kl_loss: 3.9083
# Epoch 10/30
# 547/547 [==============================] - 20s 36ms/step - total_loss: 151.1762 - reconstruction_loss: 147.2771 - kl_loss: 3.8991
# Epoch 11/30
# 547/547 [==============================] - 20s 37ms/step - total_loss: 150.6059 - reconstruction_loss: 146.7141 - kl_loss: 3.8917
# Epoch 12/30
# 547/547 [==============================] - 21s 38ms/step - total_loss: 150.0970 - reconstruction_loss: 146.2171 - kl_loss: 3.8799
# Epoch 13/30
# 547/547 [==============================] - 19s 34ms/step - total_loss: 149.6869 - reconstruction_loss: 145.8080 - kl_loss: 3.8787
# Epoch 14/30
# 547/547 [==============================] - 21s 38ms/step - total_loss: 149.3409 - reconstruction_loss: 145.4792 - kl_loss: 3.8617
# Epoch 15/30
# 547/547 [==============================] - 22s 41ms/step - total_loss: 148.9222 - reconstruction_loss: 145.0657 - kl_loss: 3.8565
# Epoch 16/30
# 547/547 [==============================] - 20s 36ms/step - total_loss: 148.5201 - reconstruction_loss: 144.6799 - kl_loss: 3.8404
# Epoch 17/30
# 547/547 [==============================] - 23s 42ms/step - total_loss: 148.3473 - reconstruction_loss: 144.5180 - kl_loss: 3.8293
# Epoch 18/30
# 547/547 [==============================] - 24s 43ms/step - total_loss: 148.0291 - reconstruction_loss: 144.2102 - kl_loss: 3.8190
# Epoch 19/30
# 547/547 [==============================] - 14s 26ms/step - total_loss: 147.7230 - reconstruction_loss: 143.9116 - kl_loss: 3.8114
# Epoch 20/30
# 547/547 [==============================] - 19s 35ms/step - total_loss: 147.4013 - reconstruction_loss: 143.5893 - kl_loss: 3.8119
# Epoch 21/30
# 547/547 [==============================] - 18s 33ms/step - total_loss: 147.2719 - reconstruction_loss: 143.4651 - kl_loss: 3.8067
# Epoch 22/30
# 547/547 [==============================] - 15s 27ms/step - total_loss: 147.0724 - reconstruction_loss: 143.2821 - kl_loss: 3.7904
# Epoch 23/30
# 547/547 [==============================] - 15s 27ms/step - total_loss: 146.7447 - reconstruction_loss: 142.9588 - kl_loss: 3.7859
# Epoch 24/30
# 547/547 [==============================] - 15s 27ms/step - total_loss: 146.6201 - reconstruction_loss: 142.8448 - kl_loss: 3.7753
# Epoch 25/30
# 547/547 [==============================] - 15s 27ms/step - total_loss: 146.4169 - reconstruction_loss: 142.6367 - kl_loss: 3.7802
# Epoch 26/30
# 547/547 [==============================] - 15s 27ms/step - total_loss: 146.2131 - reconstruction_loss: 142.4386 - kl_loss: 3.7744
# Epoch 27/30
# 547/547 [==============================] - 15s 27ms/step - total_loss: 146.1467 - reconstruction_loss: 142.3597 - kl_loss: 3.7870
# Epoch 28/30
# 547/547 [==============================] - 14s 26ms/step - total_loss: 145.9068 - reconstruction_loss: 142.1243 - kl_loss: 3.7826
# Epoch 29/30
# 547/547 [==============================] - 14s 26ms/step - total_loss: 145.7930 - reconstruction_loss: 142.0133 - kl_loss: 3.7796
# Epoch 30/30
# 547/547 [==============================] - 15s 27ms/step - total_loss: 145.6848 - reconstruction_loss: 141.9037 - kl_loss: 3.7810

# %%
import matplotlib.pyplot as plt

n = 30
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))

# 二次元グリッドで点を線形的にサンプリング
grid_x = np.linspace(-1, 1, n)
grid_y = np.linspace(-1, 1, n)[::-1]

# グリッドの角いちを順番に処理
for i, yi in enumerate(grid_y):
    for j, xi in enumerate(grid_x):

        # 各位置で数字をサンプリングし、図に追加
        z_sample = np.array([[xi, yi]])
        x_decoded = vae.decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)

        figure[i * digit_size : (i + 1) * digit_size,
               j * digit_size : (j + 1) * digit_size] = digit

plt.figure(figsize=(15, 15))
start_range = digit_size // 2
end_range = n * digit_size + start_range
pixel_range = np.arange(start_range, end_range, digit_size)
sample_range_x = np.round(grid_x, 1)
sample_range_y = np.round(grid_y, 1)
plt.xticks(pixel_range, sample_range_x)
plt.yticks(pixel_range, sample_range_y)
plt.xlabel("z[0]")
plt.ylabel("z[1]")
plt.axis("off")
plt.imshow(figure, cmap="Greys_r")
